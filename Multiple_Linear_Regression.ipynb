# %% [markdown]
# <a href="https://colab.research.google.com/github/zeeshan-ahmed-ai-tech/Machine-Learning/blob/main/Multiple_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# ----- Sample Data (X = features) -----
# Columns: [Size(sqft), Bedrooms, Age]
X = np.array([
    [2100, 3, 15],
    [1600, 2, 10],
    [2400, 4, 20],
    [1416, 2, 8],
    [3000, 4, 30]
])

# ----- Target variable (Price) -----
y = np.array([400000, 330000, 369000, 232000, 540000])

# ----- Create and train model -----
model = LinearRegression()
model.fit(X, y)

# ----- Print coefficients -----
print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)

# ----- Predict a new house price -----
new_house = np.array([[2500, 3, 15]])   # size=2500, bedrooms=3, age=15
predicted_price = model.predict(new_house)

print("Predicted Price:", predicted_price[0])
# Out:
# Coefficients: [    646.83456562 -130319.77818854  -21055.45286506]
# Intercept: -245742.60628465726
# Predicted Price: 664552.6802218109
